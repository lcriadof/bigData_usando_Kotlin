// %%
%useLatestDescriptors
%use dataframe
// Out:
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@3db46ccccaa1291c0627307d64133317f545e6ae/core/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_DataFrame"] = function(f) {f();};
//                         window.kotlinQueues["DataFrame"].forEach(function(f) {f();});
//                         window.kotlinQueues["DataFrame"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_DataFrame"] = function(f) {};
//                         window.kotlinQueues["DataFrame"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource DataFrame';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//                 <style>
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//                 </style>

// %% [markdown]
// Pruebas de dataframes en kotlin (mediante jupyter)
// TFM: Luis Criado Fernández

// %%
// basado en la documentación https://github.com/Kotlin/dataframe/blob/master/examples/notebooks/puzzles/40%20puzzles.ipynb

// %%
import org.jetbrains.dataframe.*

// %%
val raw_df = DataFrame.readCSV(fileOrUrl = "UD2_N03_vgsales.csv", delimiter = ',')
raw_df.head()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1560281088"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 11</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"Rank: Int\">Rank</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5</span></span>"] },
// { name: "<span title=\"Name: String\">Name</span>", children: [], rightAlign: false, values: ["Wii Sports","Super Mario Bros.","Mario Kart Wii","Wii Sports Resort","Pokemon Red/Pokemon Blue"] },
// { name: "<span title=\"Platform: String\">Platform</span>", children: [], rightAlign: false, values: ["Wii","NES","Wii","Wii","GB"] },
// { name: "<span title=\"Year: Int\">Year</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">2006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1985</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2009</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1996</span></span>"] },
// { name: "<span title=\"Genre: String\">Genre</span>", children: [], rightAlign: false, values: ["Sports","Platform","Racing","Sports","Role-Playing"] },
// { name: "<span title=\"Publisher: String\">Publisher</span>", children: [], rightAlign: false, values: ["Nintendo","Nintendo","Nintendo","Nintendo","Nintendo"] },
// { name: "<span title=\"NA_Sales: Double\">NA_Sales</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">4149,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2908,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1585,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1575,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1127,0</span></span>"] },
// { name: "<span title=\"EU_Sales: Double\">EU_Sales</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">2902,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">358,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1288,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1101,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">889,0</span></span>"] },
// { name: "<span title=\"JP_Sales: Double\">JP_Sales</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">377,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">681,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">379,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">328,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1022,0</span></span>"] },
// { name: "<span title=\"Other_Sales: Double\">Other_Sales</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">846,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">77,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">331,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">296,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1,0</span></span>"] },
// { name: "<span title=\"Global_Sales: Double\">Global_Sales</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">8274,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4024,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3582,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">33,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3137,0</span></span>"] },
// ], id: -1560281088, rootId: -1560281088, totalRows: 5 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-1560281088) });
//
//
//         </script>
//         </html>

// %%
// obtenemos un resumen de los tipos que tiene el dataframe
raw_df.schema()
// Out:
// Rank: Int
// Name: String
// Platform: String
// Year: Int?
// Genre: String
// Publisher: String?
// NA_Sales: Double
// EU_Sales: Double
// JP_Sales: Double
// Other_Sales: Double
// Global_Sales: Double

// %%
raw_df.describe()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1560281087"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 11, columnsCount = 12</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"name: String\">name</span>", children: [], rightAlign: false, values: ["Rank","Name","Platform","Year","Genre","Publisher","NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"] },
// { name: "<span title=\"type: Any\">type</span>", children: [], rightAlign: false, values: ["Int","String","String","Int?","String","String?","Double","Double","Double","Double","Double"] },
// { name: "<span title=\"count: Int\">count</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>"] },
// { name: "<span title=\"unique: Int\">unique</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">11493</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">31</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">40</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">12</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">579</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">369</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">276</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">218</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">144</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">559</span></span>"] },
// { name: "<span title=\"nulls: Int\">nulls</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">271</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">58</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>"] },
// { name: "<span title=\"top: Comparable\">top</span>", children: [], rightAlign: false, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","Need for Speed: Most Wanted","DS","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2009</span></span>","Action","Electronic Arts","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,0</span></span>"] },
// { name: "<span title=\"freq: Int\">freq</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">12</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2163</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1431</span></span>","<s

// %% [markdown]
// Con describe() obtenemos un detalle de todo el dataframe:
//
// Por un lado:
//
//  **count**: el número de valores no nulos en cada columna.
//
//  **min**: el valor mínimo de cada columna.
//
//  **max**: el valor máximo de cada columna.
//
//  **unique**: el número de valores únicos de cada columna categórica, es decir, el número de valores diferentes que hay en la columna.
//
//  **nulls**: el número de valores nulos de cada columna, es decir, el número de valores que no tienen ningún dato.
//
//
// Pero también nos facilita medidas de dispersión estadísticas como:
//
//  **mean**: la media aritmética de cada columna.
//
//  **std**: la desviación estándar de cada columna.
//
//  **median**: la mediana de cada columna numérica, es decir, el valor que divide la distribución en dos partes iguales.
//
//  **top**: es la moda de cada columna categórica, es decir, el valor que más se repite.
//
//  **freq**: es la frecuencia absoluta de la moda de cada columna categórica, es decir, el número de veces que se repite el valor más común.

// %%
// si queremos, por ejemplo ver solo la std
raw_df.describe()["std"]
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1560281086"></table>
//
// <p class="dataframe_description">DataColumn: name = "std", type = Double?, size = 11</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"std: Double?\">std</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">4791,853933</span></span>","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5,828981</span></span>","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">78,349852</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">48,218139</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">28,782765</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18,468917</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">147,464438</span></span>"] },
// ], id: -1560281086, rootId: -1560281086, totalRows: 11 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-1560281086) });
//
//
//         </script>
//         </html>

// %%
// nos podemos quedar solo con las columnas numéricas, facilmente, ademas en la operación limiamos los nulls asignando al año 1966
var df_num=raw_df["Rank", "Year", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales"]
    // imputing
    .fillNulls { Year }.with { 1966 }
    
df_num.describe()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1560281085"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 7, columnsCount = 12</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"name: String\">name</span>", children: [], rightAlign: false, values: ["Rank","Year","NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"] },
// { name: "<span title=\"type: Any\">type</span>", children: [], rightAlign: false, values: ["Int","Int","Double","Double","Double","Double","Double"] },
// { name: "<span title=\"count: Int\">count</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>"] },
// { name: "<span title=\"unique: Int\">unique</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">16598</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">40</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">369</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">276</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">218</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">144</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">559</span></span>"] },
// { name: "<span title=\"nulls: Int\">nulls</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>"] },
// { name: "<span title=\"top: Number\">top</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2009</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,0</span></span>"] },
// { name: "<span title=\"freq: Int\">freq</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1431</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4499</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5730</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10455</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6477</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1315</span></span>"] },
// { name: "<span title=\"mean: Double\">mean</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">8300,605254</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2005,746716</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">24,277202</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13,363297</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7,008736</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4,496686</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">48,544584</span></span>"] },
// { name: "<span title=\"std: Double\">std</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">4791,8

// %%
// filtramos entre los años 2006 y 2008
raw_df.filter { Year in 2006..2008 }
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1560281084"></table>
//
// <p class="dataframe_description">... showing only top 20 of 3638 rows</p><p class="dataframe_description">DataFrame: rowsCount = 3638, columnsCount = 11</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"Rank: Int\">Rank</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">14</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">21</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">40</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">44</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">49</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">52</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">57</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">71</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">75</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">81</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">86</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">89</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">99</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">101</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">119</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">121</span></span>"] },
// { name: "<span title=\"Name: String\">Name</span>", children: [], rightAlign: false, values: ["Wii Sports","Mario Kart Wii","New Super Mario Bros.","Wii Play","Wii Fit","Pokemon Diamond/Pokemon Pearl","Super Smash Bros. Brawl","Halo 3","Super Mario Galaxy","Grand Theft Auto IV","Grand Theft Auto IV","Call of Duty 4: Modern Warfare","Mario Party DS","Mario Party 8","Mario &#38; Sonic at the Olympic Games","Pok&#233;mon Platinum Version","Call of Duty: World at War","The Legend of Zelda: Twilight Princess","Gears of War 2","Call of Duty 4: Modern Warfare"] },
// { name: "<span title=\"Platform: String\">Platform</span>", children: [], rightAlign: false, values: ["Wii","Wii","DS","Wii","Wii","DS","Wii","X360","Wii","X360","PS3","X360","DS","Wii","Wii","DS","X360","Wii","X360","PS3"] },
// { name: "<span title=\"Year: Int\">Year</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">2006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2007</span></span>"] },
// { name: "<span title=\"Genre: String\">Genre</span>", children: [], rightAlign: false, values: ["Sports","Racing","Platform","Misc","Sports","Role-Playing","Fighting","Shooter","Platform","Action","Action","Shooter","Misc"

// %%
// contamos registros agrupado por años
var df_years=df_num.groupBy { Year }.count()
// los ordenamos
df_years.sortBy(df_years.Year)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1560281083"></table>
//
// <p class="dataframe_description">... showing only top 20 of 40 rows</p><p class="dataframe_description">DataFrame: rowsCount = 40, columnsCount = 2</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"Year: Int\">Year</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1966</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1980</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1981</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1982</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1983</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1984</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1985</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1986</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1987</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1988</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1989</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1990</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1991</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1992</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1993</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1994</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1995</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1996</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1997</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1998</span></span>"] },
// { name: "<span title=\"count: Int\">count</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">271</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">46</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">36</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">17</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">14</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">14</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">21</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">15</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">17</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">41</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">43</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">60</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">121</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">219</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">263</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">289</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">379</span></span>"] },
// ], id: -1560281083, rootId: -1560281083, totalRows: 40 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-1560281083) });
//
//
//         </script>
//         </html>

// %%
// Nos quedamos con unos pocos años
var df=raw_df.filter { Year in 2016..2018 }

var df_years2=df.groupBy { Year }.count()
println(df_years2)
// Out:
//    Year count
//  0 2016   344
//  1 2017     3
