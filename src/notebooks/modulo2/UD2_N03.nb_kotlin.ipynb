// %%
%useLatestDescriptors
%use dataframe

// %% [markdown]
// Pruebas de dataframes en kotlin (mediante jupyter)
// TFM: Luis Criado Fernández

// %%
// basado en la documentación https://github.com/Kotlin/dataframe/blob/master/examples/notebooks/puzzles/40%20puzzles.ipynb

// %%
val raw_df = DataFrame.readCSV(fileOrUrl = "UD2_N03_vgsales.csv", delimiter = ',')
raw_df.head()
// Out:
//             <iframe onload="o_resize_iframe_out_7()" style="width:100%;" class="result_container" id="iframe_out_7" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
// ...

// %%
// obtenemos un resumen de los tipos que tiene el dataframe
raw_df.schema()
// Out:
// Rank: Int
// Name: String
// Platform: String
// Year: Int?
// Genre: String
// Publisher: String?
// NA_Sales: Double
// EU_Sales: Double
// JP_Sales: Double
// Other_Sales: Double
// Global_Sales: Double

// %%
raw_df.describe()
// Out:
//             <iframe onload="o_resize_iframe_out_8()" style="width:100%;" class="result_container" id="iframe_out_8" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
// ...

// %% [markdown]
// Con describe() obtenemos un detalle de todo el dataframe:
//
// Por un lado:
//
//  **count**: el número de valores no nulos en cada columna.
//
//  **min**: el valor mínimo de cada columna.
//
//  **max**: el valor máximo de cada columna.
//
//  **unique**: el número de valores únicos de cada columna categórica, es decir, el número de valores diferentes que hay en la columna.
//
//  **nulls**: el número de valores nulos de cada columna, es decir, el número de valores que no tienen ningún dato.
//
//
// Pero también nos facilita medidas de dispersión estadísticas como:
//
//  **mean**: la media aritmética de cada columna.
//
//  **std**: la desviación estándar de cada columna.
//
//  **median**: la mediana de cada columna numérica, es decir, el valor que divide la distribución en dos partes iguales.
//
//  **top**: es la moda de cada columna categórica, es decir, el valor que más se repite.
//
//  **freq**: es la frecuencia absoluta de la moda de cada columna categórica, es decir, el número de veces que se repite el valor más común.

// %%
raw_df.forEach {
    println(it)
}
// Out:
// { Rank:1, Name:Wii Sports, Platform:Wii, Year:2006, Genre:Sports, Publisher:Nintendo, NA_Sales:4149,000000, EU_Sales:2902,000000, JP_Sales:377,000000, Other_Sales:846,000000, Global_Sales:8274,000000 }
// { Rank:2, Name:Super Mario Bros., Platform:NES, Year:1985, Genre:Platform, Publisher:Nintendo, NA_Sales:2908,000000, EU_Sales:358,000000, JP_Sales:681,000000, Other_Sales:77,000000, Global_Sales:4024,000000 }
// { Rank:3, Name:Mario Kart Wii, Platform:Wii, Year:2008, Genre:Racing, Publisher:Nintendo, NA_Sales:1585,000000, EU_Sales:1288,000000, JP_Sales:379,000000, Other_Sales:331,000000, Global_Sales:3582,000000 }
// { Rank:4, Name:Wii Sports Resort, Platform:Wii, Year:2009, Genre:Sports, Publisher:Nintendo, NA_Sales:1575,000000, EU_Sales:1101,000000, JP_Sales:328,000000, Other_Sales:296,000000, Global_Sales:33,000000 }
// ...

// %%
// si queremos, por ejemplo ver solo la std
raw_df.describe()["std"]
// Out:
//             <iframe onload="o_resize_iframe_out_9()" style="width:100%;" class="result_container" id="iframe_out_9" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
// ...

// %%
// nos podemos quedar solo con las columnas numéricas, facilmente, ademas en la operación limiamos los nulls asignando al año 1966
var df_num=raw_df["Rank", "Year", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales"]
    // imputing
    .fillNulls { Year }.with { 1966 }
    
df_num.describe()
// Out:
//             <iframe onload="o_resize_iframe_out_10()" style="width:100%;" class="result_container" id="iframe_out_10" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
// ...

// %%
// filtramos entre los años 2006 y 2008
raw_df.filter { Year in 2006..2008 }
// Out:
//             <iframe onload="o_resize_iframe_out_11()" style="width:100%;" class="result_container" id="iframe_out_11" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
// ...

// %%
// contamos registros agrupado por años
var df_years=df_num.groupBy { Year }.count()
// los ordenamos
df_years.sortBy(df_years.Year)
// Out:
//             <iframe onload="o_resize_iframe_out_12()" style="width:100%;" class="result_container" id="iframe_out_12" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
// ...

// %%
// Nos quedamos con unos pocos años
var df=raw_df.filter { Year in 2016..2018 }

var df_years2=df.groupBy { Year }.count()
println(df_years2)
// Out:
//    Year count
//  0 2016   344
//  1 2017     3
